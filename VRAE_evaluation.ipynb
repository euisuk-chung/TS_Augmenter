# %%
from utils.visualization import *
import pandas as pd
import sys
import os

# %%
from os import listdir
from os.path import isfile, join

# %%
train_loc = './gen_data_vae/train/'
train_loc
# Out:
# './gen_data_vae/train/'

# %%
train_files = []
for f in listdir(train_loc):
    train_files.append(train_loc + f)
train_files
# Out:
# ['./gen_data_vae/train/VRAE_Robust_un_False_hidden_2_win_30_ep_1000.csv',
#  './gen_data_vae/train/original_MinMax_un_False.csv',
#  './gen_data_vae/train/VRAE_MinMax_un_False_hidden_2_win_30_ep_1000.csv',
#  './gen_data_vae/train/VRAE_Standard_un_False_hidden_2_win_30_ep_1000.csv',
#  './gen_data_vae/train/VRAE_MinMax_un_False_hidden_1_win_30_ep_1000.csv',
#  './gen_data_vae/train/VRAE_Robust_un_False_hidden_1_win_30_ep_1000.csv',
#  './gen_data_vae/train/original_Standard_un_False.csv',
#  './gen_data_vae/train/original_Robust_un_False.csv',
#  './gen_data_vae/train/VRAE_MinMax_un_False_hidden_1_win_30_ep_1.csv',
#  './gen_data_vae/train/VRAE_Standard_un_False_hidden_1_win_30_ep_1000.csv']

# %%
test_loc = './gen_data_vae/test/'
test_loc
# Out:
# './gen_data_vae/test/'

# %%
test_files = []
for f in listdir(test_loc):
    test_files.append(test_loc + f)
test_files
# Out:
# ['./gen_data_vae/test/VRAE_Robust_un_False_hidden_2_win_30_ep_1000.csv',
#  './gen_data_vae/test/original_MinMax_un_False.csv',
#  './gen_data_vae/test/VRAE_MinMax_un_False_hidden_2_win_30_ep_1000.csv',
#  './gen_data_vae/test/VRAE_Standard_un_False_hidden_2_win_30_ep_1000.csv',
#  './gen_data_vae/test/VRAE_MinMax_un_False_hidden_1_win_30_ep_1000.csv',
#  './gen_data_vae/test/VRAE_Robust_un_False_hidden_1_win_30_ep_1000.csv',
#  './gen_data_vae/test/original_Standard_un_False.csv',
#  './gen_data_vae/test/original_Robust_un_False.csv',
#  './gen_data_vae/test/VRAE_MinMax_un_False_hidden_1_win_30_ep_1.csv',
#  './gen_data_vae/test/VRAE_Standard_un_False_hidden_1_win_30_ep_1000.csv']

# %%
org_train = pd.read_csv('./gen_data_vae/train/original_MinMax_un_False.csv')
print(org_train.shape)
org_train.head()
# Out:
# (22363, 92)
#    Device2Port1_AVG_INBPS  Device2Port1_AVG_OUTBPS  Device2Port4_AVG_INBPS  \
# 0                0.000366                 0.000025                0.000029
# 1                0.000267                 0.000033                0.000031
# 2                0.000202                 0.000014                0.000030
# 3                0.000207                 0.000016                0.000032
# 4                0.000215                 0.000029                0.000032
#
#    Device2Port4_AVG_OUTBPS  Device2Port6_AVG_INBPS  Device2Port6_AVG_OUTBPS  \
# 0                 0.003035                0.000010                 0.000570
# 1                 0.002222                0.000007                 0.000119
# 2                 0.002376                0.000003                 0.000085
# 3                 0.002685                0.000006                 0.000122
# 4                 0.002191                0.000003                 0.000050
#
# ...

# %%
gen_train = pd.read_csv('./gen_data_vae/train/VRAE_MinMax_un_False_hidden_2_win_30_ep_1000.csv')
print(gen_train.shape)
gen_train.head()
# Out:
# (8790, 92)
#    Device2Port1_AVG_INBPS  Device2Port1_AVG_OUTBPS  Device2Port4_AVG_INBPS  \
# 0                0.002221                 0.000560               -0.000113
# 1                0.001835                 0.000949                0.000437
# 2                0.001928                 0.000997                0.000139
# 3                0.002019                 0.001029                0.000200
# 4                0.002159                 0.000995                0.000241
#
#    Device2Port4_AVG_OUTBPS  Device2Port6_AVG_INBPS  Device2Port6_AVG_OUTBPS  \
# 0                -0.001568                0.002760                 0.005018
# 1                -0.001209                0.002188                 0.003900
# 2                -0.001952                0.002287                 0.004490
# 3                -0.001668                0.002435                 0.004577
# 4                -0.001499                0.002459                 0.004628
#
# ...
